# %% [markdown]
# # Blog Feedback
#
# **Dataset:** blog (regression)
#
# **Monotone features:**
# - Increasing: `feature_50`, `feature_51`, `feature_52`, `feature_53`, `feature_55`, `feature_56`, `feature_57`, `feature_58`, `feature_59`
#
# **Budget:** 25 trials per flavor × 4 flavors (larger feature space). Final eval: 5 seeds, best-3-of-5.

# %%
from benchmarks._common.search import run_dataset

# Per-dataset budget defaults live in benchmarks/_common/search.py (_BUDGET).
# Override here if exploring, e.g. run_dataset("auto", n_trials=20).
paths = run_dataset("blog", backend="torch", storage_dir="../results/phase2")
print("wrote:", [p.name for p in paths])
